# %%
from openai import OpenAI
import os
client = OpenAI()
response = client.images.create_variation(
  image=open("../../Image/Tesla.png", "rb"),
  n=2,
  size="1024x1024"
)

image_url = response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-qNspblSzFGoI39XaSD4cCBxl/user-nwguYZKePHCt7mNiZGpsvWff/img-PNUSjao0puPlWkWVrzBL5Q6E.png?st=2024-02-21T14%3A13%3A32Z&se=2024-02-21T16%3A13%3A32Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-21T14%3A30%3A14Z&ske=2024-02-22T14%3A30%3A14Z&sks=b&skv=2021-08-06&sig=iONyYLpQuXRoqAxGRVx8QOSZj%2BdnxnHCI2zvrknHj6M%3D

# %% [markdown]
# ## Original Image

# %%
Image(filename="../../Image/Tesla.png")

# %% [markdown]
# ## Generated Image

# %%
from IPython.display import Image
Image(url=image_url)
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-qNspblSzFGoI39XaSD4cCBxl/user-nwguYZKePHCt7mNiZGpsvWff/img-PNUSjao0puPlWkWVrzBL5Q6E.png?st=2024-02-21T14%3A13%3A32Z&se=2024-02-21T16%3A13%3A32Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-21T14%3A30%3A14Z&ske=2024-02-22T14%3A30%3A14Z&sks=b&skv=2021-08-06&sig=iONyYLpQuXRoqAxGRVx8QOSZj%2BdnxnHCI2zvrknHj6M%3D"/>
